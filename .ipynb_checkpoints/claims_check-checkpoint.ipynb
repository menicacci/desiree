# %%
from scripts import check_claim_structure as cs
from scripts import table
from scripts import utils
from scripts import eval

# %%
answers_path = 'experiments/output/cs_dataset/6/answers'
output_path = 'experiments/output/cs_dataset/6/claims.json'
tables_file_path = 'experiments/extracted_tables/cs_tables.json'

claims = cs.extract_answers(answers_path, output_path)
extracted_tables = table.load_tables_from_json(tables_file_path)

# %%
eval.evaluate_extracted_articles(claims, extracted_tables)
# Out:
# [['2110.05362-0', 1.0],
#  ['2301.04770-0', 1.0],
#  ['2301.04770-2', 1.0],
#  ['2307.01231-1', 1.0],
#  ['2110.05362-4', 0.9929601230034677],
#  ['2304.12329-3', 0.9923942877106419],
#  ['1912.01728-2', 0.9901842054881571],
#  ['2110.05362-2', 0.9880257335167899],
#  ['2304.12329-5', 0.9844987062648877],
#  ['2110.05362-1', 0.9554777518709701],
#  ['2110.05362-6', 0.9501347689243113],
#  ['1701.08288-0', 0.9465016737857225],
#  ['2307.01231-6', 0.9425389755011137],
#  ['2303.03132-2', 0.9415952718957469],
#  ['1912.01728-0', 0.9414225941422595],
#  ['1912.01728-1', 0.9290322580645162],
#  ['2301.04770-1', 0.9196172248803828],
#  ['2110.05362-3', 0.9110588318400596],
#  ['2303.03132-1', 0.9030907121985703],
#  ['2303.03132-3', 0.900513616695749],
#  ['1806.07524-0', 0.8992820149786289],
#  ['2307.01231-3', 0.8909378118505832],
#  ['1701.08288-1', 0.8802094016069507],
#  ['2303.03132-5', 0.8662950807038916],
#  ['2307.01231-7', 0.8518277341650129],
# ...

# %%
utils.print_claims(claims, print_all=False, article_id='2303.03132')
# Out:
# Article ID: 2303.03132
# 	Table Index: 0
# 		Extracted Claims:
# 			specifications:
# 				DS: A-B,
# 				A: 1,081,
# 				B: 1,092,
# 				Pos. Pairs Train: 616,
# 				Neg. Pairs Train: 5,127,
# 				Pos. Pairs Val./Test: 206,
# 				Neg. Pairs Val./Test: 1,710,
# 				Vocabulary Size: 7,879,
# 				Max. Matching Neighbours in B: 2,
# 				Cartesian Product: 1M,
# 			measure: None
# 			outcome: None
#
#
# 			specifications:
# 				DS: A-G,
# 				A: 1,363,
# 				B: 3,266,
# 				Pos. Pairs Train: 699,
# 				Neg. Pairs Train: 6,175,
# 				Pos. Pairs Val./Test: 234,
# 				Neg. Pairs Val./Test: 2,059,
# 				Vocabulary Size: 7,389,
# 				Max. Matching Neighbours in B: 2,
# 				Cartesian Product: 4M,
# 			measure: None
# 			outcome: None
#
#
# 			specifications:
# 				DS: W-A,
# 				A: 2,554,
# 				B: 22,074,
# 				Pos. Pairs Train: 576,
# 				Neg. Pairs Train: 5,568,
# 				Pos. Pairs Val./Test: 193,
# 				Neg. Pairs Val./Test: 856,
# 				Vocabulary Size: 49,156,
# ...

# %%
article_id = '2303.03132'
table_idx = 4

html_table = extracted_tables[article_id][table_idx]['table']
table_vales, table_df = cs.get_table_values(html_table)

table_vales
# Out:
# ['1.2k',
#  '1.4k',
#  '1.5k',
#  '1.8k',
#  '1.9k',
#  '100k',
#  '101',
#  '109.8k',
#  '119.6k',
#  '11k',
#  '125',
#  '133',
#  '14k',
#  '157',
#  '185',
#  '188',
#  '1k',
#  '2.1k',
#  '2.4k',
#  '2.6k',
#  '2.7k',
#  '2.9k',
#  '20M',
#  '212',
#  '216',
#  '2198',
#  '228',
#  '22k',
#  '246.1k',
#  '250k',
#  '27.9k',
#  '296',
#  '2k',
#  '3.6k',
#  '3.7k',
#  '30.7k',
#  '303',
#  '31k',
#  '32.47%',
#  '335',
#  '336',
#  '346',
#  '351',
#  '353',
#  '355',
#  '36.2%',
#  '37k',
#  '383',
#  '39.8%',
#  '3k',
#  '4.2k',
#  '41.6%',
#  '41k',
#  '43.1%',
#  '43.2%',
#  '437',
#  '44.0%',
#  '44.4%',
#  '442',
#  '45.1%',
#  '46.2k',
#  '467',
#  '49.1%',
#  '490',
#  '4k',
#  '50.3%',
#  '50.5%',
#  '500k',
#  '51.3%',
#  '51.6%',
#  '511',
#  '548',
#  '555',
#  '56.5%',
#  '57',
#  '57.7%',
#  '58.1%',
#  '58.3%',
#  '59.4%',
#  '5M',
#  '5k',
#  '6.3k',
#  '606',
#  '61.0%',
#  '61.4%',
#  '62.9%',
#  '63.8%',
#  '63.9%',
#  '64.2%',
#  '64.3%',
#  '65.8%',
# ...

# %%
claims_data = claims[article_id][table_idx]['extracted_claims']
specs_extracted, results_extracted, values_extracted = cs.count_specifications(claims_data)

utils.print_specifications(specs_extracted)
utils.print_results_map(results_extracted)

values_extracted
# Out:
# Specification: Blocker
# Count: 144
# Values:
#   SC-Block: 72
#   BT: 72
#
# Specification: Matcher
# Count: 144
# Values:
#   SupCon: 36
#   Ditto: 36
#   CE: 36
#   Mag.: 36
#
# Specification: Dataset
# Count: 144
# Values:
#   A-B: 24
#   A-G: 24
#   W-A: 24
#   WDC-B small: 24
#   WDC-B medium: 24
#   WDC-B large: 24
#
# Measure: Candidate set size
# Total count: 48
# Outcomes:
#   5k
#   11k
#   31k
#   70k
#   100k
#   5M
#   5k
#   11k
#   31k
#   70k
#   100k
#   5M
#   5k
#   11k
#   31k
#   70k
#   100k
#   5M
#   5k
#   11k
#   31k
#   70k
#   100k
#   5M
#   22k
#   41k
#   66k
#   250k
#   500k
#   20M
#   22k
#   41k
#   66k
#   250k
#   500k
#   20M
#   22k
#   41k
#   66k
#   250k
#   500k
#   20M
#   22k
#   41k
#   66k
#   250k
#   500k
#   20M
#
# Measure: F1 score
# Total count: 48
# Outcomes:
#   92.6%
#   80.3%
#   80.8%
#   70.5%
#   71.8%
#   71.7%
#   90.7%
#   75.7%
#   85.6%
#   76.8%
#   78.2%
#   77.5%
#   80.0%
#   64.2%
#   85.6%
#   77.1%
#   77.0%
# ...

# %%
import difflib

def find_similar_strings(input_list, search_list, threshold=0.6):
    similar_strings = {}
    for item in input_list:
        item_lower = item.lower()
        similar_strings[item] = []
        original_match_found = False
        # Check for exact match
        for string in search_list:
            string_lower = string.lower()
            if item_lower == string_lower:
                similar_strings[item] = [string]
                original_match_found = True
                break

        if not original_match_found:
            # Check for similar substrings
            for sub_item in item.split():
                sub_item_lower = sub_item.lower()
                for string in search_list:
                    string_lower = string.lower()
                    similarity_ratio = difflib.SequenceMatcher(None, sub_item_lower, string_lower).ratio()
                    if similarity_ratio >= threshold:
                        similar_strings[item].append(string)

    # Remove similar strings within each result
    for item, matches in similar_strings.items():
        if len(matches) > 1:
            to_remove = set()
            for i in range(len(matches)):
                for j in range(i + 1, len(matches)):
                    similarity_ratio = difflib.SequenceMatcher(None, matches[i], matches[j]).ratio()
                    if similarity_ratio >= threshold:
                        similarity_to_item_i = difflib.SequenceMatcher(None, item.lower(), matches[i].lower()).ratio()
                        similarity_to_item_j = difflib.SequenceMatcher(None, item.lower(), matches[j].lower()).ratio()

                        if similarity_to_item_i > similarity_to_item_j:
                            to_remove.add(matches[j])
                        else:
                            to_remove.add(matches[i])

            similar_strings[item] = [m for m in matches if m not in to_remove]

    return similar_strings

find_similar_strings(table_vales, values_extracted)
# Out:
# {'1.2k': ['1.2k s'],
#  '1.4k': ['1.4k s', '61.4%'],
#  '1.5k': ['1.5k s', '5k'],
#  '1.8k': ['109.8k s', '71.8%'],
#  '1.9k': ['2.9k s'],
#  '100k': ['100k'],
#  '101': ['101s', '11k'],
#  '109.8k': ['100k', '109.8k s'],
#  '119.6k': ['119.6k s', '11k'],
#  '11k': ['11k'],
#  '125': ['125s'],
#  '133': ['133s'],
#  '14k': ['1.4k s', '41k'],
#  '157': ['157s'],
#  '185': ['185s'],
#  '188': ['188s'],
#  '1k': ['100k', '1k s', '41k'],
#  '2.1k': ['2.1k s'],
#  '2.4k': ['2.4k s', '32.47%'],
#  '2.6k': ['2.6k s', '92.6%'],
#  '2.7k': ['2.7k s', '32.47%'],
#  '2.9k': ['2.9k s', '92.9%'],
#  '20M': ['20M'],
#  '212': ['212s', '22k'],
#  '216': [],
#  '2198': ['2198s'],
#  '228': ['22k'],
#  '22k': ['22k'],
#  '246.1k': ['246.1k s', '41k'],
#  '250k': ['250k'],
#  '27.9k': ['27.9k s', '92.9%'],
#  '296': ['296s'],
#  '2k': ['22k', '250k'],
#  '3.6k': ['2.6k s'],
#  '3.7k': ['30.7k s', '32.47%'],
#  '30.7k': ['30.7k s', '90.7%'],
#  '303': ['303s'],
#  '31k': ['31k'],
# ...
